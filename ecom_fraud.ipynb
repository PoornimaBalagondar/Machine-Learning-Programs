# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,RobustScaler,OrdinalEncoder,StandardScaler,TargetEncoder
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor
from sklearn.svm import SVR
from xgboost import XGBClassifier,XGBRegressor

# %%
df=pd.read_csv("/content/ecom_fraud.csv")
df.head(4)
# Out:
#    transaction_id  user_id         timestamp_utc  amount_aed currency  \
# 0       500086758  1000466  2024-01-01T00:02:03Z       71.47      AED
# 1       500060464  1002828  2024-01-01T00:03:11Z       70.25      AED
# 2       500039909  1010349  2024-01-01T00:04:10Z      116.25      AED
# 3       500074412  1015360  2024-01-01T00:05:14Z       99.41      AED
#
#   payment_method device_type browser merchant_category  items_count  ...  \
# 0           card     desktop  Chrome          Pharmacy            3  ...
# 1           card      mobile  Chrome         Groceries            1  ...
# 2  bank_transfer     desktop  Chrome            Beauty            2  ...
# 3      apple_pay      mobile  Safari              Toys            2  ...
#
#    local_hour odd_hour is_fraud  fraud_flag_ip fraud_flag_mismatch  \
# 0           4        1        0              0                   0
# 1           4        1        0              0                   0
# 2           4        1        0              0                   0
# 3           4        1        0              0                   0
#
#    fraud_flag_velocity  fraud_flag_new_account fraud_flag_prev_cb  \
# 0                    0                       0                  0
# 1                    0                       1                  0
# 2                    0                       0                  0
# 3                    0                       0                  0
#
#    fraud_flag_odd_hour                  data_source
# 0                    1  synthetic:ecom-fraud-uae-v1
# 1                    1  synthetic:ecom-fraud-uae-v1
# 2                    1  synthetic:ecom-fraud-uae-v1
# 3                    1  synthetic:ecom-fraud-uae-v1
#
# [4 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   transaction_id          100000 non-null  int64
#  1   user_id                 100000 non-null  int64
#  2   timestamp_utc           100000 non-null  object
#  3   amount_aed              100000 non-null  float64
#  4   currency                100000 non-null  object
#  5   payment_method          100000 non-null  object
#  6   device_type             100000 non-null  object
#  7   browser                 100000 non-null  object
#  8   merchant_category       100000 non-null  object
#  9   items_count             100000 non-null  int64
#  10  avg_item_price          100000 non-null  float64
#  11  shipping_city           100000 non-null  object
#  12  billing_city            100000 non-null  object
#  13  shipping_billing_match  100000 non-null  int64
#  14  ip_address              100000 non-null  object
#  15  ip_risk_score           100000 non-null  float64
#  16  card_present            100000 non-null  int64
#  17  bin_country             100000 non-null  object
#  18  card_age_days           100000 non-null  int64
#  19  card_country_match      100000 non-null  int64
#  20  email_domain            100000 non-null  object
#  21  user_prev_chargebacks   100000 non-null  int64
#  22  user_is_high_risk       100000 non-null  int64
#  23  user_account_age_days   100000 non-null  int64
#  24  transactions_last_24h   100000 non-null  int64
#  25  transactions_last_1h    100000 non-null  int64
#  26  local_hour              100000 non-null  int64
#  27  odd_hour                100000 non-null  int64
#  28  is_fraud                100000 non-null  int64
#  29  fraud_flag_ip           100000 non-null  int64
#  30  fraud_flag_mismatch     100000 non-null  int64
#  31  fraud_flag_velocity     100000 non-null  int64
#  32  fraud_flag_new_account  100000 non-null  int64
#  33  fraud_flag_prev_cb      100000 non-null  int64
#  34  fraud_flag_odd_hour     100000 non-null  int64
#  35  data_source             100000 non-null  object
# dtypes: float64(3), int64(21), object(12)
# memory usage: 27.5+ MB

# %%
cat_col=df.select_dtypes(exclude='number').columns

# %%
df[cat_col]=df[cat_col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   transaction_id          100000 non-null  int64
#  1   user_id                 100000 non-null  int64
#  2   timestamp_utc           100000 non-null  category
#  3   amount_aed              100000 non-null  float64
#  4   currency                100000 non-null  category
#  5   payment_method          100000 non-null  category
#  6   device_type             100000 non-null  category
#  7   browser                 100000 non-null  category
#  8   merchant_category       100000 non-null  category
#  9   items_count             100000 non-null  int64
#  10  avg_item_price          100000 non-null  float64
#  11  shipping_city           100000 non-null  category
#  12  billing_city            100000 non-null  category
#  13  shipping_billing_match  100000 non-null  int64
#  14  ip_address              100000 non-null  category
#  15  ip_risk_score           100000 non-null  float64
#  16  card_present            100000 non-null  int64
#  17  bin_country             100000 non-null  category
#  18  card_age_days           100000 non-null  int64
#  19  card_country_match      100000 non-null  int64
#  20  email_domain            100000 non-null  category
#  21  user_prev_chargebacks   100000 non-null  int64
#  22  user_is_high_risk       100000 non-null  int64
#  23  user_account_age_days   100000 non-null  int64
#  24  transactions_last_24h   100000 non-null  int64
#  25  transactions_last_1h    100000 non-null  int64
#  26  local_hour              100000 non-null  int64
#  27  odd_hour                100000 non-null  int64
#  28  is_fraud                100000 non-null  int64
#  29  fraud_flag_ip           100000 non-null  int64
#  30  fraud_flag_mismatch     100000 non-null  int64
#  31  fraud_flag_velocity     100000 non-null  int64
#  32  fraud_flag_new_account  100000 non-null  int64
#  33  fraud_flag_prev_cb      100000 non-null  int64
#  34  fraud_flag_odd_hour     100000 non-null  int64
#  35  data_source             100000 non-null  category
# dtypes: category(12), float64(3), int64(21)
# memory usage: 25.6 MB

# %%
x=df.drop('is_fraud',axis=1)
y=df['is_fraud']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
model=XGBClassifier(enable_categorical=True)
model.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model.score(xtrain,ytrain)
# Out:
# 0.931325

# %%
model.score(xtest,ytest)
# Out:
# 0.9149
